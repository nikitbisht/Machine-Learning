# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement (3).csv')

# %%
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel("CGPA")
plt.ylabel("PACKAGE")
# Out:
# Text(0, 0.5, 'PACKAGE')

# %%
X = df.iloc[:,0:1];
y = df.iloc[:,1];

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=2)

# %%
X_train
# Out:
#      cgpa
# 137  7.14
# 163  8.93
# 111  5.42
# 123  5.10
# 109  7.77
# ..    ...
# 43   7.66
# 22   6.14
# 72   7.78
# 15   7.25
# 168  8.65
#
# [160 rows x 1 columns]

# %%
y_train
# Out:
# 137    3.13
# 163    3.91
# 111    2.25
# 123    2.30
# 109    4.06
#        ...
# 43     2.76
# 22     2.30
# 72     3.62
# 15     3.23
# 168    3.52
# Name: package, Length: 160, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel("CGPA")
plt.ylabel("PACKAGE")
# Out:
# Text(0, 0.5, 'PACKAGE')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
y_pred = lr.predict(X_test)

# %%
print("Mean Absoulte error",mean_absolute_error(y_test,y_pred))
# Out:
# Mean Absoulte error 0.2884710931878175

# %%
print("Mean Square error",mean_squared_error(y_test,y_pred))
# Out:
# Mean Square error 0.12129235313495527

# %%
print("Root Mean Square error",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# Root Mean Square error 0.34827051717731616

# %%
r2 = r2_score(y_test,y_pred)
print("R2 Score",r2)
# Out:
# R2 Score 0.780730147510384

# %%
print("Adjusted R2 Score")
1 - (((1-r2)*(40-1))/(40-1-1))
# Out:
# Adjusted R2 Score
# 0.7749598882343415

# %%
new_df = df.copy()
new_df['random_col'] = np.random.random(200)
new_df = new_df[['cgpa','random_col','package']]

# %%
new_df
# Out:
#      cgpa  random_col  package
# 0    6.89    0.560245     3.26
# 1    5.12    0.384028     1.98
# 2    7.82    0.396240     3.25
# 3    7.42    0.144516     3.67
# 4    6.94    0.223566     3.57
# ..    ...         ...      ...
# 195  6.93    0.165954     2.46
# 196  5.89    0.395221     2.57
# 197  7.21    0.185828     3.24
# 198  7.63    0.007859     3.96
# 199  6.22    0.344343     2.33
#
# [200 rows x 3 columns]

# %%
plt.scatter(new_df['random_col'],new_df['package'])
plt.xlabel("random")
plt.ylabel("PACKAGE")
# Out:
# Text(0, 0.5, 'PACKAGE')

# %%
X = new_df.iloc[:,0:2]
y = new_df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=2)

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
r2 = r2_score(y_test,y_pred)
print("R2 Score",r2)
# Out:
# R2 Score 0.7818091785035666

# %%
print("Adjusted R2 Score")
1 - (((1-r2)*(40-1))/(40-1-1))
# Out:
# Adjusted R2 Score
# 0.7760673147799763

# %%
new_df2 = df.copy()

new_df2['iq'] = new_df2['package'] + (np.random.randint(-12,12,200)/10)

new_df2 = new_df2[['cgpa','iq','package']]

# %%
new_df2.sample(5)
# Out:
#      cgpa    iq  package
# 116  9.04  3.03     3.33
# 112  8.58  3.00     4.10
# 171  8.01  3.36     3.76
# 158  5.95  3.34     3.04
# 60   5.61  1.29     2.19

# %%
plt.scatter(new_df2['iq'],new_df2['package'])
plt.xlabel('iq')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
np.random.randint(-100,100)
# Out:
# 6

# %%
X = new_df2.iloc[:,0:2]
y = new_df2.iloc[:,-1]

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)

# %%
print("R2 score",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 score 0.7818091785035666

# %%
1 - ((1-r2)*(40-1)/(40-1-2))
# Out:
# 0.7700150800442999
